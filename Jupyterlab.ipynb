# %% [markdown]
# Introducing Someone and their holiday preference with a picture and a link to a youtube video of this holiday preference

# %%
a=input('Name:')
# Out:
# Name:HELLO

# %% [markdown]
# ![someone.svg](attachment:someone.svg)

# %%
a=input('Your preferred holiday would be ')
b=input('The ideal holiday destination is ')
c=input('Month of the holiday is ')
# Out:
# Your preferred holiday would be aaaa
# The ideal holiday destination is a
# Month of the holiday is a

# %% [markdown]
# ![holiday.jpg](attachment:holiday.jpg)

# %% [markdown]
# The top three things that Someone likes to do during holidays:
#
# *Number one thing
#
# *Number two thing
#
# *Number three thing

# %%
print("\033[1;36;33m LOOKING FORWARD TO THE HOLIDAY \n")
# Out:
#  LOOKING FORWARD TO THE HOLIDAY

# %% [markdown]
# THIS HOLIDAY ON YOUTUBE: https://www.youtube.com/watch?v=0NrEY_jQQHw
